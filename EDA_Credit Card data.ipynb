# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns

# set the graphs to show in the jupyter notebook
# %matplotlib inline

# %%
source='E:/Analytics Labs/python_CaseStudy/Python Foundation Case Study 2 - Credit Card Case Study/'
Cust_Acq = pd.read_csv(source+'Customer Acqusition.csv')
Repayment = pd.read_csv(source+'Repayment.csv')
Spend = pd.read_csv(source+'spend.csv')

# %%
Cust_Acq
# Out:
#      No Customer  Age        City   Product     Limit Company        Segment
# 0     1       A1   76   BANGALORE      Gold  500000.0      C1  Self Employed
# 1     2       A2   71    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2     3       A3   34      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3     4       A4   47      BOMBAY  Platimum   10001.0      C4           Govt
# 4     5       A5   56   BANGALORE  Platimum   10002.0      C5  Normal Salary
# ..  ...      ...  ...         ...       ...       ...     ...            ...
# 95   96      A96   54     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96   97      A97   58  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97   98      A98   51    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98   99      A99   35    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99  100     A100   36      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 8 columns]

# %%
Cust_Acq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No        100 non-null    int64
#  1   Customer  100 non-null    object
#  2   Age       100 non-null    int64
#  3   City      100 non-null    object
#  4   Product   100 non-null    object
#  5   Limit     100 non-null    float64
#  6   Company   100 non-null    object
#  7   Segment   100 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 6.4+ KB

# %%
Repayment
# Out:
#       SL No: Customer      Month     Amount  Unnamed: 4
# 0        NaN       A1  12-Jan-04  495414.75         NaN
# 1        2.0       A1   3-Jan-04  245899.02         NaN
# 2        3.0       A1  15-Jan-04  259490.06         NaN
# 3        4.0       A1  25-Jan-04  437555.12         NaN
# 4        5.0       A1  17-Jan-05  165972.88         NaN
# ...      ...      ...        ...        ...         ...
# 1518     NaN      NaN        NaN        NaN         NaN
# 1519     NaN      NaN        NaN        NaN         NaN
# 1520     NaN      NaN        NaN        NaN         NaN
# 1521     NaN      NaN        NaN        NaN         NaN
# 1522     NaN      NaN        NaN        NaN         NaN
#
# [1523 rows x 5 columns]

# %%
Repayment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1523 entries, 0 to 1522
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SL No:      1499 non-null   float64
#  1   Customer    1500 non-null   object
#  2   Month       1500 non-null   object
#  3   Amount      1500 non-null   float64
#  4   Unnamed: 4  0 non-null      float64
# dtypes: float64(3), object(2)
# memory usage: 59.6+ KB

# %%
Spend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sl No:    1500 non-null   int64
#  1   Customer  1500 non-null   object
#  2   Month     1500 non-null   object
#  3   Type      1500 non-null   object
#  4   Amount    1500 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 58.7+ KB

# %%
print(Cust_Acq.shape)
print(Repayment.shape)
print(Spend.shape)
# Out:
# (100, 8)
# (1523, 5)
# (1500, 5)

# %%
Cust_Acq.dtypes
# Out:
# No            int64
# Customer     object
# Age           int64
# City         object
# Product      object
# Limit       float64
# Company      object
# Segment      object
# dtype: object

# %%
Repayment.dtypes
# Out:
# SL No:        float64
# Customer       object
# Month          object
# Amount        float64
# Unnamed: 4    float64
# dtype: object

# %%
Spend.dtypes
# Out:
# Sl No:        int64
# Customer     object
# Month        object
# Type         object
# Amount      float64
# dtype: object

# %%
Spend.isnull().sum()
# Out:
# Sl No:      0
# Customer    0
# Month       0
# Type        0
# Amount      0
# dtype: int64

# %%
Repayment.isnull().sum()
# Out:
# SL No:          24
# Customer        23
# Month           23
# Amount          23
# Unnamed: 4    1523
# dtype: int64

# %%
Cust_Acq.isnull().sum()
# Out:
# No          0
# Customer    0
# Age         0
# City        0
# Product     0
# Limit       0
# Company     0
# Segment     0
# dtype: int64

# %%
Repayment.drop(['Unnamed: 4'], axis = 1, inplace = True)
Repayment.isnull().sum()
# Out:
# SL No:      24
# Customer    23
# Month       23
# Amount      23
# dtype: int64

# %%
Repayment[Repayment.isnull().any(axis=1)]
# Out:
#       SL No: Customer      Month     Amount
# 0        NaN       A1  12-Jan-04  495414.75
# 1500     NaN      NaN        NaN        NaN
# 1501     NaN      NaN        NaN        NaN
# 1502     NaN      NaN        NaN        NaN
# 1503     NaN      NaN        NaN        NaN
# 1504     NaN      NaN        NaN        NaN
# 1505     NaN      NaN        NaN        NaN
# 1506     NaN      NaN        NaN        NaN
# 1507     NaN      NaN        NaN        NaN
# 1508     NaN      NaN        NaN        NaN
# 1509     NaN      NaN        NaN        NaN
# 1510     NaN      NaN        NaN        NaN
# 1511     NaN      NaN        NaN        NaN
# 1512     NaN      NaN        NaN        NaN
# 1513     NaN      NaN        NaN        NaN
# 1514     NaN      NaN        NaN        NaN
# 1515     NaN      NaN        NaN        NaN
# 1516     NaN      NaN        NaN        NaN
# 1517     NaN      NaN        NaN        NaN
# 1518     NaN      NaN        NaN        NaN
# ...

# %%
# SL No. is assigned to the records in order, so we will give it the value '1.0',and drop other records
Repayment.loc[0,'SL No:']= 1.0

# %%
Repayment.dropna(axis=0, how='all', inplace= True)

# %%
Repayment.isnull().sum()
# Out:
# SL No:      0
# Customer    0
# Month       0
# Amount      0
# dtype: int64

# %%
Cust_Acq.head()
# Out:
#    No Customer  Age       City   Product     Limit Company        Segment
# 0   1       A1   76  BANGALORE      Gold  500000.0      C1  Self Employed
# 1   2       A2   71   CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2   3       A3   34     COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3   4       A4   47     BOMBAY  Platimum   10001.0      C4           Govt
# 4   5       A5   56  BANGALORE  Platimum   10002.0      C5  Normal Salary

# %%
Repayment.head()
# Out:
#    SL No: Customer      Month     Amount
# 0     1.0       A1  12-Jan-04  495414.75
# 1     2.0       A1   3-Jan-04  245899.02
# 2     3.0       A1  15-Jan-04  259490.06
# 3     4.0       A1  25-Jan-04  437555.12
# 4     5.0       A1  17-Jan-05  165972.88

# %%
Spend.head()
# Out:
#    Sl No: Customer      Month       Type     Amount
# 0       1       A1  12-Jan-04  JEWELLERY  485470.80
# 1       2       A1   3-Jan-04      PETRO  410556.13
# 2       3       A1  15-Jan-04    CLOTHES   23740.46
# 3       4       A1  25-Jan-04       FOOD  484342.47
# 4       5       A1  17-Jan-05     CAMERA  369694.07

# %% [markdown]
# ### 1.a. In case age is less than 18, replace it with mean of age values

# %%
Cust_Acq.loc[Cust_Acq.Age<18,'Age']=Cust_Acq.Age.mean()

# %%
Cust_Acq.loc[Cust_Acq.Age<18,'Age'].count()
# Out:
# 0

# %% [markdown]
# ### 1.b. In case spend amount is more than the limit, replace it with 50% of that customer’s limit. (customer’s limit provided in acquisition table is the per transaction limit on his card)

# %%
Spend_cust = pd.merge(left= Spend, right= Cust_Acq, on='Customer', how="left")
Spend_cust.head(2)
# Out:
#    Sl No: Customer      Month       Type     Amount  No   Age       City  \
# 0       1       A1  12-Jan-04  JEWELLERY  485470.80   1  76.0  BANGALORE
# 1       2       A1   3-Jan-04      PETRO  410556.13   1  76.0  BANGALORE
#
#   Product     Limit Company        Segment
# 0    Gold  500000.0      C1  Self Employed
# 1    Gold  500000.0      C1  Self Employed

# %%
Spend_cust.loc[ Spend_cust.Amount > Spend_cust.Limit,'Amount'] = (50 * Spend_cust.Limit).div(100)

# %%
Spend_cust.loc[ Spend_cust.Amount > Spend_cust.Limit,'Amount'].count()
# Out:
# 0

# %% [markdown]
# ### 1.c. Incase the repayment amount is more than the limit, replace the repayment with the limit.

# %%
Repay_Cust = pd.merge( left = Repayment, right = Cust_Acq, how = 'left', on ='Customer' )
Repay_Cust.head(2)
# Out:
#    SL No: Customer      Month     Amount  No   Age       City Product  \
# 0     1.0       A1  12-Jan-04  495414.75   1  76.0  BANGALORE    Gold
# 1     2.0       A1   3-Jan-04  245899.02   1  76.0  BANGALORE    Gold
#
#       Limit Company        Segment
# 0  500000.0      C1  Self Employed
# 1  500000.0      C1  Self Employed

# %%
Repay_Cust.loc[ Repay_Cust.Amount > Repay_Cust.Limit , 'Amount' ]= Repay_Cust.Limit

# %%
Repay_Cust.loc[ Repay_Cust.Amount > Repay_Cust.Limit , 'Amount' ].count()
# Out:
# 0

# %% [markdown]
# ### 2. From the above dataset create the following summaries:
# ###  2.a. How many distinct customers exist?

# %%
distinct_customers = Cust_Acq["Customer"].nunique()

# %%
print("Number of distinct customers are",distinct_customers)
# Out:
# Number of distinct customers are 100

# %% [markdown]
# ###  2.b. How many distinct categories exist?

# %%
print('The number of distinct categories are',Cust_Acq["Segment"].nunique())
# Out:
# The number of distinct categories are 5

# %% [markdown]
# ###  2.c. What is the average monthly spend by customers?

# %%
Spend['Month']=pd.to_datetime(Spend['Month'], format = '%d-%b-%y')

# %%
Spend.head(3)
# Out:
#    Sl No: Customer      Month       Type     Amount
# 0       1       A1 2004-01-12  JEWELLERY  485470.80
# 1       2       A1 2004-01-03      PETRO  410556.13
# 2       3       A1 2004-01-15    CLOTHES   23740.46

# %%
Spend.groupby(Spend['Month'].dt.strftime('%Y-%b'))['Amount'].mean()
# Out:
# Month
# 2004-Apr    235272.037143
# 2004-Feb    221215.270000
# 2004-Jan    251712.068664
# 2004-Mar    232146.119286
# 2004-May    217539.236429
# 2004-Nov    270486.397857
# 2004-Sep    310923.383571
# 2005-Apr    252181.326429
# 2005-Aug    233734.634286
# 2005-Dec    147503.060000
# 2005-Feb    229802.279821
# 2005-Jan    292741.372857
# 2005-Jul    229116.663571
# 2005-Jun    262688.112857
# 2005-May    245696.515429
# 2005-Nov    286143.322857
# 2005-Oct    194568.640714
# 2005-Sep    188666.202143
# 2006-Apr    232468.967553
# 2006-Aug    240699.717143
# 2006-Dec    270470.980714
# 2006-Feb    253858.260714
# 2006-Jan    282058.006429
# 2006-Jul    287505.098929
# 2006-Jun    177252.386429
# 2006-Mar    247166.084654
# 2006-May    236162.740357
# 2006-Nov    182841.290000
# 2006-Oct    236136.335000
# 2006-Sep    158520.090714
# Name: Amount, dtype: float64

# %% [markdown]
# ###  2.d. What is the average monthly repayment by customers?

# %%
Repayment['Month']= pd.to_datetime(Repayment['Month'], format = '%d-%b-%y')

# %%
Repayment.groupby(Repayment['Month'].dt.strftime('%Y-%b'))['Amount'].mean()
# Out:
# Month
# 2004-Apr    259141.679000
# 2004-Feb    256702.630741
# 2004-Jan    243489.649786
# 2004-Mar    252585.280667
# 2004-May    226162.720800
# 2004-Nov    209592.238000
# 2004-Sep    184487.848750
# 2005-Apr    212688.631333
# 2005-Aug    264430.921622
# 2005-Dec    320379.335833
# 2005-Feb    238829.265123
# 2005-Jan    240548.098148
# 2005-Jul    239871.479167
# 2005-Jun    210199.818333
# 2005-May    263207.367857
# 2005-Nov    256695.120000
# 2005-Oct    219849.956667
# 2005-Sep    247700.170000
# 2006-Apr    275472.251889
# 2006-Aug    224143.992500
# 2006-Dec    252736.569167
# 2006-Feb    284489.565128
# 2006-Jan    293475.389167
# 2006-Jul    257936.383243
# 2006-Jun    251990.453333
# 2006-Mar    240851.266814
# 2006-May    256920.884943
# 2006-Nov    199399.197407
# 2006-Oct    260765.480000
# 2006-Sep    262533.880833
# Name: Amount, dtype: float64

# %% [markdown]
# ###  2.e. If the monthly rate of interest is 2.9%, what is the profit for the bank for each month? (Profit is defined as interest earned on Monthly Profit. Monthly Profit = Monthly repayment – Monthly spend. Interest is earned only on positive profits and not on negative amounts)

# %%
Spend['Monthly'] = Spend['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%B"))
Spend['Yearly'] = Spend['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%Y"))

# %%
customer_spend = round(Spend.groupby(['Yearly','Monthly'])[['Amount']].sum().reset_index(),2)
customer_spend.head()
# Out:
#   Yearly   Monthly       Amount
# 0   2004     April   6587617.04
# 1   2004  February   6194027.56
# 2   2004   January  77275605.08
# 3   2004     March   3250045.67
# 4   2004       May   3045549.31

# %%
Repayment['Monthly'] = Repayment['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%B"))
Repayment['Yearly'] = Repayment['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%Y"))

# %%
customer_repay= round(Repayment.groupby(['Yearly','Monthly'])[['Amount']].sum().reset_index(),2)
customer_repay.head()
# Out:
#   Yearly   Monthly       Amount
# 0   2004     April   7774250.37
# 1   2004  February   6930971.03
# 2   2004   January  68177101.94
# 3   2004     March   3788779.21
# 4   2004       May   5654068.02

# %%
profit = pd.merge(left = customer_repay, right = customer_spend ,how= 'inner', on=['Yearly','Monthly'], suffixes=('_repay', '_spend'))
profit.head()
# Out:
#   Yearly   Monthly  Amount_repay  Amount_spend
# 0   2004     April    7774250.37    6587617.04
# 1   2004  February    6930971.03    6194027.56
# 2   2004   January   68177101.94   77275605.08
# 3   2004     March    3788779.21    3250045.67
# 4   2004       May    5654068.02    3045549.31

# %%
profit[['Monthly Profit']] = profit.Amount_repay - profit.Amount_spend
profit.head()
# Out:
#   Yearly   Monthly  Amount_repay  Amount_spend  Monthly Profit
# 0   2004     April    7774250.37    6587617.04      1186633.33
# 1   2004  February    6930971.03    6194027.56       736943.47
# 2   2004   January   68177101.94   77275605.08     -9098503.14
# 3   2004     March    3788779.21    3250045.67       538733.54
# 4   2004       May    5654068.02    3045549.31      2608518.71

# %%
profit['Bank_Profit'] = np.where(profit['Monthly Profit']>0 ,profit['Monthly Profit']*0.029,0)

# %%
profit.head()
# Out:
#   Yearly   Monthly  Amount_repay  Amount_spend  Monthly Profit  Bank_Profit
# 0   2004     April    7774250.37    6587617.04      1186633.33  34412.36657
# 1   2004  February    6930971.03    6194027.56       736943.47  21371.36063
# 2   2004   January   68177101.94   77275605.08     -9098503.14      0.00000
# 3   2004     March    3788779.21    3250045.67       538733.54  15623.27266
# 4   2004       May    5654068.02    3045549.31      2608518.71  75647.04259

# %% [markdown]
# ###  2.f. What are the top 5 product types?

# %%
Spend.head()
# Out:
#    Sl No: Customer      Month       Type     Amount  Monthly Yearly
# 0       1       A1 2004-01-12  JEWELLERY  485470.80  January   2004
# 1       2       A1 2004-01-03      PETRO  410556.13  January   2004
# 2       3       A1 2004-01-15    CLOTHES   23740.46  January   2004
# 3       4       A1 2004-01-25       FOOD  484342.47  January   2004
# 4       5       A1 2005-01-17     CAMERA  369694.07  January   2005

# %%
# top 5 product types onthe basis of 
Spend.groupby(['Type'])[['Amount']].sum().reset_index().sort_values(by='Amount',
                                                                    ascending=False, 
                                                                    ignore_index=True).head(5)
# Out:
#            Type       Amount
# 0         PETRO  49863174.09
# 1        CAMERA  41481571.96
# 2          FOOD  37773338.43
# 3  TRAIN TICKET  33067077.15
# 4    AIR TICKET  32955445.42

# %%
#merging customer and spend table on the basis of "Customer" column
#customer_spend = pd.merge(left=Cust_Acq,right=Spend,on="Customer",how="inner")

#Spend_cust = pd.merge(left= Spend, right= Cust_Acq, on='Customer', how="left")
#Spend_cust.head(2)

# %% [markdown]
# ###  2.g. Which city is having maximum spend?

# %%
cust_spend= pd.merge(left=Cust_Acq, 
                     right=Spend, 
                     on='Customer', 
                     how = 'inner')
cust_spend.head(5)
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount  Monthly Yearly
# 0       1 2004-01-12  JEWELLERY  485470.80  January   2004
# 1       2 2004-01-03      PETRO  410556.13  January   2004
# 2       3 2004-01-15    CLOTHES   23740.46  January   2004
# 3       4 2004-01-25       FOOD  484342.47  January   2004
# 4       5 2005-01-17     CAMERA  369694.07  January   2005

# %%
# the top city having maximum spend
cust_spend.groupby(['City'])[['Amount']].sum().reset_index().sort_values(by = 'Amount', 
                                                                         ascending = False, 
                                                                         ignore_index=True).head(1)
# Out:
#      City       Amount
# 0  COCHIN  73495349.26

# %% [markdown]
# ###  2.h. Which age group is spending more money?

# %%
cust_spend['AgeGroup'] = pd.cut(cust_spend['Age'], 
                                bins=[0,18,35,50,65,100],
                                labels=['0-18','18-35','35-50','50-65','65-100'],
                                right=False)

# %%
cust_spend.head(2)
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount  Monthly Yearly AgeGroup
# 0       1 2004-01-12  JEWELLERY  485470.80  January   2004   65-100
# 1       2 2004-01-03      PETRO  410556.13  January   2004   65-100

# %%
cust_spend.groupby(['AgeGroup'])[['Amount']].sum().reset_index().sort_values(by='Amount',
                                                                             ascending = False,
                                                                             ignore_index=True).head(1)
# Out:
#   AgeGroup        Amount
# 0    35-50  1.153324e+08

# %% [markdown]
# ###  2.i. Who are the top 10 customers in terms of repayment?

# %%
Repayment.groupby(['Customer'])[['Amount']].sum().reset_index().sort_values(by='Amount', 
                                                                            ascending=False,
                                                                            ignore_index=True).head(10)
# Out:
#   Customer       Amount
# 0      A61  10539142.91
# 1      A60   9876290.74
# 2      A13   9572000.66
# 3      A22   9372561.68
# 4      A21   9056336.15
# 5      A43   8489871.46
# 6      A45   8448334.87
# 7      A12   8334760.16
# 8      A48   8292416.75
# 9      A14   7943268.63

# %% [markdown]
# ### 3. Calculate the city wise spend on each product on yearly basis. Also include a graphical representation for the same.

# %%
customer_spend_pivot = pd.pivot_table(data = cust_spend,
                                      index=["City","Yearly"],
                                      columns='Product',
                                      aggfunc="sum",
                                      values="Amount")
customer_spend_pivot
# Out:
# Product                   Gold     Platimum      Silver
# City       Yearly
# BANGALORE  2004     9289878.54   6046763.93  6773901.65
#            2005    12892362.99   7784194.68  3936068.22
#            2006    12030611.09   5620904.86  4967945.66
# BOMBAY     2004     6987853.53   5199581.00  3061805.08
#            2005     8983018.28   5134074.48  2368375.97
#            2006     7917144.31   7547549.72  3628864.37
# CALCUTTA   2004     7477140.98   5961165.93  3321963.10
#            2005    10303355.80   8810284.03  1285609.11
#            2006    11167532.77  11305526.03  4783182.26
# CHENNAI    2004     1059618.50   5558572.68  1156129.37
#            2005     3740945.58   8868435.43  1000540.48
#            2006     2704288.62   6921130.79  1665326.62
# COCHIN     2004     7315850.15   8472832.23  4587738.70
#            2005    12110613.03  10856722.82  2619231.25
#            2006    10499142.38  12453968.83  4579249.87
# ...

# %%
customer_spend_pivot.plot(kind="bar",figsize=(18,5),width=0.8)
plt.ylabel("Spend Amount")
plt.title("Amount spended by customers according to year and city")
plt.show()

# %% [markdown]
# ### 4. Create graphs for
# ### a. Monthly comparison of total spends, city wise

# %%
piv_4a = pd.pivot_table(data = cust_spend, 
                        index=['Yearly','Monthly'], 
                        columns= 'City', 
                        values="Amount",
                        aggfunc='sum')

# %%
piv_4a_2004 = piv_4a.loc['2004']
piv_4a_2005 = piv_4a.loc['2005']
piv_4a_2006 = piv_4a.loc['2006']

# %%
piv_4a_2004.plot(kind="bar",figsize=(18,6),width=0.8)
plt.ylabel("Spend Amount")
plt.title("Monthly comparison of total spends, city wise for year 2004")
plt.show()

# %%
piv_4a_2005.plot(kind="bar",figsize=(18,6),width=0.8)
plt.ylabel("Spend Amount")
plt.title("Monthly comparison of total spends, city wise for year 2005")
plt.show()

# %%
piv_4a_2006.plot(kind="bar",figsize=(18,6),width=0.8)
plt.ylabel("Spend Amount")
plt.title("Monthly comparison of total spends, city wise for year 2006")
plt.show()

# %% [markdown]
# ###  b. Comparison of yearly spend on air tickets

# %%
cust_spend.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount  Monthly Yearly AgeGroup
# 0       1 2004-01-12  JEWELLERY  485470.80  January   2004   65-100
# 1       2 2004-01-03      PETRO  410556.13  January   2004   65-100
# 2       3 2004-01-15    CLOTHES   23740.46  January   2004   65-100
# 3       4 2004-01-25       FOOD  484342.47  January   2004   65-100
# 4       5 2005-01-17     CAMERA  369694.07  January   2005   65-100

# %%
spend_at = cust_spend[cust_spend.Type == 'AIR TICKET'].groupby(['Yearly'])[['Amount']].sum()

# %%
spend_at.plot(kind="bar",width=0.8)
plt.ylabel("Spend Amount")
plt.title("Yearly Comparison of spend on air tickets")
plt.show()

# %% [markdown]
# ###  c. Comparison of monthly spend for each product (look for any seasonality that exists in terms of spend)

# %%
piv_4c= pd.pivot_table(data = cust_spend,
               index = ['Yearly','Monthly'],
               columns = 'Product',
               values="Amount",
               aggfunc = 'sum')
piv_4c
# Out:
# Product                  Gold     Platimum       Silver
# Yearly Monthly
# 2004   April       2690380.77   1819712.63   2077523.64
#        February    3198850.31   1769237.83   1225939.42
#        January    28837092.88  28795654.56  19642857.64
#        March       1092661.79   1030013.96   1127369.92
#        May         1601677.48    818552.99    625318.84
#        November     659981.60   1629263.62   1497564.35
#        September   1343862.61   1816183.55   1192881.21
# 2005   April       2646922.16   3097516.32   1316638.66
#        August      2925282.74   2581877.78   1037409.24
#        December     664762.18   1001201.85    399078.81
#        February   17359157.23  15601838.88   5645786.90
#        January     3111426.90   4068395.95   1016935.59
#        July        1121173.40   1402579.46    683880.43
#        June        5250066.70   4151149.69   1631684.35
#        May        14024090.17  14692437.76   5680984.23
# ...

# %%
piv_4c_2004 = piv_4c.loc['2004']
piv_4c_2005 = piv_4c.loc['2005']
piv_4c_2006 = piv_4c.loc['2006']

# %%
piv_4c_2004.plot(kind='bar')
plt.show()

# %% [markdown]
# For the year 2004, the sales of January are very high

# %%
piv_4c_2005.plot(kind='bar')
plt.show()

# %% [markdown]
# For the year 2005, the sales of February and May are very high

# %%
piv_4c_2006.plot(kind='bar')
plt.show()

# %% [markdown]
# For the year 2006, the sales of March is very high

# %% [markdown]
# ### 5. Write user defined PYTHON function to perform the following analysis:
# ### You need to find top 10 customers for each city in terms of their repayment amount by different products and by different time periods i.e. year or month. The user should be able to specify the product (Gold/Silver/Platinum) and time period (yearly or monthly) and the function should automatically take these inputs while identifying the top 10 customers.

# %%
Repay_Cust['Month']= pd.to_datetime(Repay_Cust['Month'], format = '%d-%b-%y')
Repay_Cust['Monthly'] = Repay_Cust['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%B"))
Repay_Cust['Yearly'] = Repay_Cust['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%Y"))

# %%
def summary_report(Product,timeperiod):
    print('Give the product name and timeperiod for which you want the data')
    if Product.lower()=='gold' and timeperiod.lower()=='monthly':
        pivot = Repay_Cust.pivot_table(index=['Product','City','Customer'],columns='Monthly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Gold',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif Product.lower()=='gold' and timeperiod.lower()=='yearly':
        pivot = Repay_Cust.pivot_table(index=['Product','City','Customer'],columns='Yearly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Gold',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif Product.lower()=='silver' and timeperiod.lower()=='monthly':
        pivot = Repay_Cust.pivot_table(index=['Product','City','Customer'],columns='Monthly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Silver',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif Product.lower()=='silver' and timeperiod.lower()=='yearly':
        pivot = Repay_Cust.pivot_table(index=['Product','City','Customer'],columns='Yearly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Silver',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    if Product.lower()=='platinum' and timeperiod.lower()=='monthly':
        pivot = Repay_Cust.pivot_table(index=['Product','City','Customer'],columns='Monthly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Platinum',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif Product.lower()=='platinum' and timeperiod.lower()=='yearly':
        pivot = Repay_Cust.pivot_table(index=['Product','City','Customer'],columns='Yearly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Platinum',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    return result

# %%
summary_report('gold','monthly')
# Out:
# Give the product name and timeperiod for which you want the data
# Monthly                           April     August   December    February  \
# Product City       Customer
# Gold    BANGALORE  A1         508949.16        NaN        NaN   781873.80
#                    A13        494392.40  873304.51        NaN  2049808.15
#                    A14        812582.20  198623.13  388821.96  1482923.34
#                    A30        425694.16        NaN        NaN  1321469.80
#                    A43        612541.80        NaN        NaN   763846.93
#                    A63              NaN        NaN        NaN         NaN
#                    A81              NaN        NaN        NaN         NaN
#                    A88              NaN        NaN        NaN         NaN
#                    A92        459105.69        NaN        NaN         NaN
#         COCHIN     A11        958466.08  332677.61        NaN  1069789.26
# ...
